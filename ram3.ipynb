# %%
import pandas as pd
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
import re
import jellyfish
pd.set_option('display.precision',15)
from pyjarowinkler import distance
df_npa = pd.read_csv(r'C:\Users\KC\Desktop\EssilorWP\NPA_ForFuzzymatches.csv', index_col=0)
df_macola = pd.read_csv(r"C:\Users\KC\Desktop\WhitespaceProject\Macola.csv")
# Out:
# C:\Users\KC\AppData\Local\Continuum\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# C:\Users\KC\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (24,26,34,38,39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_macola1 = df_macola.dropna(subset=['Practice Phone'])
df_macola1 = pd.concat([df_macola,df_macola1])
df_macola1 = df_macola1.drop_duplicates(keep=False)

# %%
df_macola1.shape
# Out:
# (15808, 26)

# %%
data = pd.read_csv(r"C:\Users\KC\Desktop\EssilorWP\ram2fuzzyvalues.txt", header = None)

# %%
for index,row in data.iterrow():
if str(row['1'][0:8]) == str(row['2'][0:8]):
    if (re.findall(r'\d+', row['1'])[1] == re.findall(r'\d+', row['2'])):
            f = open(r"C:\Users\KC\Desktop\EssilorWP\check2changes_2.txt", 'a')
            f.write(str(index) + '\n')
            f.close 
print(len(index_jf))
# Out:
#             0                              1                          2
# 0      699161           5FRANKLINAVESUITE209         5FRANKLINAVESTE209
# 1        6112                      1147HWY35              1147HIGHWAY35
# 2       11347                1651GLENNSBAYRD            1651GLENNSBAYRD
# 3       12019               111HAZELLNSTE102                 111HAZELLN
# 4       13909         7551TIMBERLAKEWYSTE100    7551TIMBERLAKEWAYSTE100
# 5       14066               301PENNAVESTE100                 301PENNAVE
# 6       14359                        2204MST                2204MSTREET
# 7       14802             888WHOUGHTONLAKEDR         888WHOUGHTONLAKEDR
# 8       15170              3900LONGBEACHBLVD          3900LONGBEACHBLVD
# 9       15171                    318NMAINAVE                318NMAINAVE
# 10      16071                 48SGREENLEAFST            48SGREENLEAFAVE
# 11      16076              2098TREMONTCENTER             2098TREMONTCTR
# ...

# %%
df = DataFrame(index=['A','B','C'], columns=['x','y'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa99c8f24463> in <module>
# ----> 1 df = DataFrame(index=['A','B','C'], columns=['x','y'])
#
# NameError: name 'DataFrame' is not defined

# %%
a = [1,2,3,5]
b = [3,5]
c = [x for x in a if x not in b]
c
