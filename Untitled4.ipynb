# %%
import jellyfish
from pyjarowinkler import distance

jellyfish.jaro_winkler('POBOX1692MORGANTON','POBOX1695MORRISTOWN')
# Out:
# 0.8814954051796157

# %%
import pandas as pd
df_npa = pd.read_csv(r'C:\Users\KC\Desktop\EssilorWP\NPA_Processed.csv', index_col=0)
df_macola = pd.read_csv(r"C:\Users\KC\Desktop\WhitespaceProject\Macola.csv")
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Other Provider Identifier')))]
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Healthcare Provider Taxonomy')))] 
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Healthcare Provider Primary Taxonomy')))]
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Provider License Numb')))]
df_npa.shape
# Out:
# (140952, 54)

# %%
import re
check = 'GOROVOY MD EYE-SPECIALISTS,12381* .S CLEVELAND AVE #300'
re.sub('[^a-zA-Z0-9]', '', check)
# Out:
# 'GOROVOYMDEYESPECIALISTS12381SCLEVELANDAVE300'

# %%
df_macola.columns
# Out:
# Index(['Macola/Company ID', 'Account Name', 'Shipping Street',
#        'Shipping Address Line 1', 'Shipping Address Line 2',
#        'Shipping Address Line 3', 'Shipping City', 'Shipping State/Province',
#        'Shipping Zip/Postal Code', 'Latitude_WD', 'Longitude_WD', 'Phone',
#        'Email - Primary', 'Website', 'Primary Lab Channel', 'Unnamed: 15',
#        'Primary Laboratory (Sales)', 'Practice Name',
#        'Practice Street Address 1', 'Practice Street Address 2',
#        'Practice City', 'Practice State', 'Practice Zip', 'Practice Phone',
#        'Practice email', 'Practice URL'],
#       dtype='object')

# %%
import re
string = 'fsfdf'
str(int(re.search(r'\d+', string)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-2afdff277203> in <module>
#       1 import re
#       2 string = 'fsfdf'
# ----> 3 str(int(re.search(r'\d+', string)))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
import re
#m = re.search('STE (\d+)|SUITE (\d+)', 'series[SUITE 37]-03th_July_2010-YouTube', re.IGNORECASE)
#m.group(1)

str = ""
a = re.findall(r'\d+', str)
print(a)
# Out:
# []

# %%
import pandas as pd
import jellyfish
from pyjarowinkler import distance
import re
df_npa = pd.read_csv(r'C:\Users\KC\Desktop\EssilorWP\NPA_Processed.csv', index_col=0)
df_macola = pd.read_csv(r"C:\Users\KC\Desktop\WhitespaceProject\Macola.csv")
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Other Provider Identifier')))]
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Healthcare Provider Taxonomy')))] 
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Healthcare Provider Primary Taxonomy')))]
df_npa = df_npa[df_npa.columns.drop(list(df_npa.filter(regex='Provider License Numb')))]

df_npa = df_npa.dropna(axis=1, how='all')

df_npa1 = df_npa.dropna(subset=['Provider Organization Name (Legal Business Name)'])
df_npa = pd.concat([df_npa,df_npa1])
df_npa = df_npa.drop_duplicates(keep=False)


'''cols = ['Shipping Address Line 1', 'Shipping Address Line 2', 'Shipping Address Line 3', 'Shipping City']
df_macola['check1'] = df_macola[cols].apply(lambda x: ','.join(x.dropna()), axis=1)
cols_npa1 = ['Provider First Line Business Mailing Address', 'Provider Second Line Business Mailing Address', 'Provider Business Mailing Address City Name']
df_npa['check1'] = df_npa[cols_npa1].apply(lambda y: ','.join(y.dropna()), axis=1)

npa_index = []
address = df_macola['check1'].tolist()
for index, row in df_npa_stage1.iterrows():
    if (row['check1'] in address):
        npa_index.append(index)
        
df_npa = df_npa.drop(npa_index)'''
# Out:
# "cols = ['Shipping Address Line 1', 'Shipping Address Line 2', 'Shipping Address Line 3', 'Shipping City']\ndf_macola['check1'] = df_macola[cols].apply(lambda x: ','.join(x.dropna()), axis=1)\ncols_npa1 = ['Provider First Line Business Mailing Address', 'Provider Second Line Business Mailing Address', 'Provider Business Mailing Address City Name']\ndf_npa['check1'] = df_npa[cols_npa1].apply(lambda y: ','.join(y.dropna()), axis=1)\n\nnpa_index = []\naddress = df_macola['check1'].tolist()\nfor index, row in df_npa_stage1.iterrows():\n    if (row['check1'] in address):\n        npa_index.append(index)\n        \ndf_npa = df_npa.drop(npa_index)"

# %%
df_macola['Shipping Address Line2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Shipping Address Line2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-e9ba948c293a> in <module>
# ----> 1 df_macola['Shipping Address Line2']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Shipping Address Line2'

# %%
s = '107S33M15H'    
prefix = s.rpartition('M')[0]
prefix
# Out:
# '107S33'

# %%
df_npa[['Provider First Line Business Mailing Address',
       'Provider Second Line Business Mailing Address',]]
# Out:
#         Provider First Line Business Mailing Address  \
# 30                                  1107 MANTUA PIKE
# 33                               169 N MIDDLETOWN RD
# 36                            31519 WINTERPLACE PKWY
# 77                                   1420 S 28TH AVE
# 89                              7815 N KNOXVILLE AVE
# 112                                     402 S COX ST
# 140                                    65 BELKNAP ST
# 180                                   3415 GOLDEN RD
# 205                              10260 WESTHEIMER RD
# 240                                2808 FORSYTHE AVE
# 249                                  14210 CULVER DR
# 256                            1400 WELLBROOK CIR NE
# 268                                  2880 DAUPHIN ST
# 296                                     PO BOX 38157
# 298                          99 US ROUTE 1 BYP STE A
# 304                                  123 HOSPITAL DR
# 306                                 660 S EUCLID AVE
# 312                                   3415 GOLDEN RD
# 332                                  1420 S 28TH AVE
# 354              2652 GEORGE WASHINGTON MEMORIAL HWY
# 377                                155 BORTHWICK AVE
# 448                             1620 COUNTRY CLUB RD
# 460                                   2935 MAPLE AVE
# 464                                   1002 SEATON LN
# 481                                   453 SUMNER AVE
# 483                           31519 WINTERPLACE PKWY
# 516                                 6770 MAYFIELD RD
# 520                           5430 FREDERICKSBURG RD
# 624                            12381 S CLEVELAND AVE
# 635                            12381 S CLEVELAND AVE
# ...                                              ...
# 6124748                          415 L ST NW APT 444
# 6124773                              2422 AMBLER AVE
# 6124832                                702 SW 8TH ST
# 6124874                           32100 TELEGRAPH RD
# 6124895                           233 SPRING ST FL 6
# 6124896                           233 SPRING ST FL 6
# 6125101                   32100 TELEGRAPH RD STE 205
# 6125150                         9700 S MCCARRAN BLVD
# 6125180                   32100 TELEGRAPH RD STE 205
# 6125240                              504 E CENTER ST
# 6125500                              6002 SLIDE ROAD
# 6125512                         140 TRINITY PL STE B
# 6125615                  2435 COMMERCE AVE BLDG 2200
# 6125619                      535 S FERDON BLVD STE B
# 6125728                               5471 NORMAN CT
# 6126108                               1616 GATES AVE
# 6126123                               2828 ALMOND ST
# 6126169                     1075 EASTON AVE STE 1-2B
# 6126268                  1950 OLD GALLOWS RD STE 520
# 6126315                             6536 SW 134TH PL
# 6126362                   32100 TELEGRAPH RD STE 205
# 6126507                            130 N BALLARD AVE
# 6126568                               3541 W 95TH ST
# 6126648                        214 N FRANKLIN AVENUE
# 6126650                           458 27TH AVE APT 4
# 6126809                  2435 COMMERCE AVE BLDG 2200
# 6126962                            1486 WATERBURY RD
# 6127159                                 PO BOX 18331
# 6127165                          5427 TIMBER POST ST
# 6127248                                201 RACINE DR
#
#         Provider Second Line Business Mailing Address
# 30                                            STE 722
# 33                                                NaN
# 36                                              STE 1
# 77                                                NaN
# 89                                                NaN
# 112                                               NaN
# 140                                             STE 1
# 180                                               NaN
# 205                                           STE 580
# 240                                               NaN
# 249                                             STE F
# 256                                           STE 100
# 268                                               NaN
# 296                                               NaN
# 298                                               NaN
# 304                                        SUITE 1002
# 306                                          C B 8096
# 312                                               NaN
# 332                                               NaN
# 354                                             STE 1
# 377                                    SUITE 200 EAST
# 448                                           SUITE D
# 460                                               NaN
# 464                                               NaN
# 481                                               NaN
# 483                                             STE 1
# 516                                           STE 338
# 520                                           STE 100
# 624                                           STE 300
# 635                                           STE 300
# ...                                               ...
# 6124748                                           NaN
# 6124773                                           NaN
# 6124832                                           NaN
# 6124874                                           NaN
# 6124895                                           NaN
# 6124896                                           NaN
# 6125101                                           NaN
# 6125150                                           NaN
# 6125180                                           NaN
# 6125240                                           NaN
# 6125500                                           NaN
# 6125512                                           NaN
# 6125615                                           NaN
# 6125619                                           NaN
# 6125728                                     BLDG 9250
# 6126108                                           NaN
# 6126123                                           NaN
# 6126169                                           NaN
# 6126268                                           NaN
# 6126315                                           NaN
# 6126362                                           NaN
# 6126507                                           NaN
# 6126568                                           NaN
# 6126648                                           NaN
# 6126650                                           NaN
# 6126809                                           NaN
# 6126962                                           NaN
# 6127159                                           NaN
# 6127165                                           NaN
# 6127248                                           NaN
#
# [140952 rows x 2 columns]

# %%
[] == []
# Out:
# True

# %%
df_npa.columns
# Out:
# Index(['NPI', 'Entity Type Code', 'Replacement NPI',
#        'Employer Identification Number (EIN)',
#        'Provider Organization Name (Legal Business Name)',
#        'Provider Last Name (Legal Name)', 'Provider First Name',
#        'Provider Middle Name', 'Provider Name Prefix Text',
#        'Provider Name Suffix Text', 'Provider Credential Text',
#        'Provider Other Organization Name',
#        'Provider Other Organization Name Type Code',
#        'Provider Other Last Name', 'Provider Other First Name',
#        'Provider Other Middle Name', 'Provider Other Name Prefix Text',
#        'Provider Other Name Suffix Text', 'Provider Other Credential Text',
#        'Provider Other Last Name Type Code',
#        'Provider First Line Business Mailing Address',
#        'Provider Second Line Business Mailing Address',
#        'Provider Business Mailing Address City Name',
#        'Provider Business Mailing Address State Name',
#        'Provider Business Mailing Address Postal Code',
#        'Provider Business Mailing Address Country Code (If outside U.S.)',
#        'Provider Business Mailing Address Telephone Number',
#        'Provider Business Mailing Address Fax Number',
#        'Provider First Line Business Practice Location Address',
#        'Provider Second Line Business Practice Location Address',
#        'Provider Business Practice Location Address City Name',
#        'Provider Business Practice Location Address State Name',
#        'Provider Business Practice Location Address Postal Code',
#        'Provider Business Practice Location Address Country Code (If outside U.S.)',
#        'Provider Business Practice Location Address Telephone Number',
#        'Provider Business Practice Location Address Fax Number',
#        'Provider Enumeration Date', 'Last Update Date',
#        'NPI Deactivation Reason Code', 'NPI Deactivation Date',
#        'NPI Reactivation Date', 'Provider Gender Code',
#        'Authorized Official Last Name', 'Authorized Official First Name',
#        'Authorized Official Middle Name',
#        'Authorized Official Title or Position',
#        'Authorized Official Telephone Number', 'Is Sole Proprietor',
#        'Is Organization Subpart', 'Parent Organization LBN',
#        'Parent Organization TIN', 'Authorized Official Name Prefix Text',
#        'Authorized Official Name Suffix Text',
#        'Authorized Official Credential Text'],
#       dtype='object')

# %%
l = [1,2,3]
b = [2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-e8ed05419ecf> in <module>
#       1 l = [1,2,3]
#       2 b = [2,3]
# ----> 3 l-b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
