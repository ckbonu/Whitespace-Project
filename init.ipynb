# %%
import pandas as pd
import re
import jellyfish
pd.set_option('display.precision',10)
from pyjarowinkler import distance
df_npa = pd.read_csv(r'C:\Users\KC\Desktop\EssilorWP\NPA_ForFuzzy.csv')
df_macola = pd.read_csv(r"C:\Users\KC\Desktop\WhitespaceProject\Macola.csv")
df_macola['Phone'] = df_macola['Phone'].astype(str)          
df_macola['Phone'] = df_macola['Phone'].str.replace('.0', ' ')
df_macola['Practice Phone'] = df_macola['Practice Phone'].astype(str)          
df_macola['Practice Phone'] = df_macola['Practice Phone'].str.replace('.0', ' ')
df_npa['Provider Business Mailing Address Telephone Number'] = df_npa['Provider Business Mailing Address Telephone Number'].astype(str)          
df_npa['Provider Business Mailing Address Telephone Number'] = df_npa['Provider Business Mailing Address Telephone Number'].str.replace('.0', ' ')
df_npa['Provider Business Practice Location Address Telephone Number'] =df_npa['Provider Business Practice Location Address Telephone Number'].astype(str)          
df_npa['Provider Business Practice Location Address Telephone Number'] =df_npa['Provider Business Practice Location Address Telephone Number'].str.replace('.0', ' ')
df_npa = df_npa.dropna(axis=1, how='all')
df_npa.shape
# Out:
# (42030, 40)

# %%
df_npa = df_npa.drop(['check1','check2'], axis=1)

# %%
cols_practice_npa = ['Provider Organization Name (Legal Business Name)','Provider First Line Business Mailing Address','Provider Second Line Business Mailing Address','Provider Business Mailing Address City Name','Provider Other Organization Name','Provider First Line Business Practice Location Address', 'Provider Second Line Business Practice Location Address','Provider Business Practice Location Address City Name']
cols_practice_macola = ['Account Name','Shipping Address Line 1', 'Shipping Address Line 2', 'Shipping Address Line 3','Shipping City','Practice Name','Practice Street Address 1', 'Practice Street Address 2','Practice City']
df_macola['check1'] = df_macola[cols_practice_macola].apply(lambda x: ','.join(x.dropna()), axis=1)
df_npa['check1'] = df_npa[cols_practice_npa].apply(lambda x: ','.join(x.dropna()), axis=1)

# %%
macolaaddresslist = df_macola.check1.tolist()
npaaddresslist = df_npa.check1.tolist()
npaphone = df_npa['Provider Business Practice Location Address Telephone Number'].tolist()

# %%
for item in macolaaddresslist:
    item1 = re.sub('[^a-zA-Z0-9]', '', item) 
    macolaaddresslist.append(item1)
    macolaaddresslist.remove(item)
for item in npaaddresslist:
    item1 = re.sub('[^a-zA-Z0-9]', '', item) 
    npaaddresslist.append(item1)
    npaaddresslist.remove(item)
for phone in npaphone:
    phone1 = re.sub('[^a-zA-Z0-9]', '', str(phone))
    npaphone.append(phone1)
    npaphone.remove(phone)

# %%
macolaid = []
for index,row in df_macola.iterrows():
    if re.sub('[^a-zA-Z0-9]', '', row['Provider Business Practice Location Address Telephone Number']) in npaphone:
# Out:
# C:\Users\KC\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_npa1
# Out:
#                 NPI  Entity Type Code Employer Identification Number (EIN)  \
# 22979    1619972734               2.0                            <UNAVAIL>
# 691704   1396781829               2.0                            <UNAVAIL>
# 1419413  1811069057               2.0                            <UNAVAIL>
# 1837748  1972633543               2.0                            <UNAVAIL>
# 1961051  1952422198               2.0                            <UNAVAIL>
# 2457361  1174700793               2.0                            <UNAVAIL>
# 2498465  1841460722               2.0                            <UNAVAIL>
# 2521565  1427220177               2.0                            <UNAVAIL>
# 2551837  1568637635               2.0                            <UNAVAIL>
# 3057484  1013248442               2.0                            <UNAVAIL>
# 3272756  1689974669               2.0                            <UNAVAIL>
# ...

# %%
df_npa1 = df_npa1.sort_values("NPI")

# %%
df_npa1
# Out:
#                 NPI  Entity Type Code Employer Identification Number (EIN)  \
# 3057484  1013248442               2.0                            <UNAVAIL>
# 3322174  1093010696               2.0                            <UNAVAIL>
# 3798644  1144578642               2.0                            <UNAVAIL>
# 2457361  1174700793               2.0                            <UNAVAIL>
# 3335588  1215233424               2.0                            <UNAVAIL>
# 691704   1396781829               2.0                            <UNAVAIL>
# 2521565  1427220177               2.0                            <UNAVAIL>
# 2551837  1568637635               2.0                            <UNAVAIL>
# 5008747  1609323849               2.0                            <UNAVAIL>
# 22979    1619972734               2.0                            <UNAVAIL>
# 3272756  1689974669               2.0                            <UNAVAIL>
# ...

# %%
df_npa1 = df_npa1.drop_duplicates(subset =['check1','Provider Business Practice Location Address Telephone Number'], 
                     keep = 'first')

# %%
df_npa1
# Out:
#                 NPI  Entity Type Code Employer Identification Number (EIN)  \
# 3057484  1013248442               2.0                            <UNAVAIL>
# 3322174  1093010696               2.0                            <UNAVAIL>
# 3798644  1144578642               2.0                            <UNAVAIL>
# 2457361  1174700793               2.0                            <UNAVAIL>
# 3335588  1215233424               2.0                            <UNAVAIL>
# 691704   1396781829               2.0                            <UNAVAIL>
# 2521565  1427220177               2.0                            <UNAVAIL>
# 5008747  1609323849               2.0                            <UNAVAIL>
# 22979    1619972734               2.0                            <UNAVAIL>
# 3272756  1689974669               2.0                            <UNAVAIL>
# 1419413  1811069057               2.0                            <UNAVAIL>
# ...

# %%
df_npa1.columns
# Out:
# Index(['NPI', 'Entity Type Code', 'Employer Identification Number (EIN)',
#        'Provider Organization Name (Legal Business Name)',
#        'Provider Other Organization Name',
#        'Provider Other Organization Name Type Code',
#        'Provider First Line Business Mailing Address',
#        'Provider Second Line Business Mailing Address',
#        'Provider Business Mailing Address City Name',
#        'Provider Business Mailing Address State Name',
#        'Provider Business Mailing Address Postal Code',
#        'Provider Business Mailing Address Country Code (If outside U.S.)',
#        'Provider Business Mailing Address Telephone Number',
#        'Provider Business Mailing Address Fax Number',
#        'Provider First Line Business Practice Location Address',
#        'Provider Second Line Business Practice Location Address',
#        'Provider Business Practice Location Address City Name',
#        'Provider Business Practice Location Address State Name',
# ...

# %%
df_macola.columns
# Out:
# Index(['Macola/Company ID', 'Account Name', 'Shipping Street',
#        'Shipping Address Line 1', 'Shipping Address Line 2',
#        'Shipping Address Line 3', 'Shipping City', 'Shipping State/Province',
#        'Shipping Zip/Postal Code', 'Latitude_WD', 'Longitude_WD', 'Phone',
#        'Email - Primary', 'Website', 'Primary Lab Channel', 'Unnamed: 15',
#        'Primary Laboratory (Sales)', 'Practice Name',
#        'Practice Street Address 1', 'Practice Street Address 2',
#        'Practice City', 'Practice State', 'Practice Zip', 'Practice Phone',
#        'Practice email', 'Practice URL'],
#       dtype='object')

# %%
df = pd.DataFrame(data={'X': [1.5, 6.777, 2.444, pd.np.NaN], 'Y': [1.111, pd.np.NaN, 8.77, pd.np.NaN], 'Z': [5.0, 2.333, 10, 6.6666]})

# %%
df
# Out:
#        X      Y        Z
# 0  1.500  1.111   5.0000
# 1  6.777    NaN   2.3330
# 2  2.444  8.770  10.0000
# 3    NaN    NaN   6.6666

# %%
ndex = ['0']
#df.loc[ndex[0],'Z'] = '3'
#df
ndex[0]
# Out:
# '0'

# %%
df_npa.count()
# Out:
# NPI                                                                           57088
# Entity Type Code                                                              57088
# Employer Identification Number (EIN)                                          57088
# Provider Organization Name (Legal Business Name)                              57088
# Provider Other Organization Name                                              23512
# Provider Other Organization Name Type Code                                    23518
# Provider First Line Business Mailing Address                                  57088
# Provider Second Line Business Mailing Address                                 16264
# Provider Business Mailing Address City Name                                   57088
# Provider Business Mailing Address State Name                                  57088
# Provider Business Mailing Address Postal Code                                 57087
# ...

# %%
number = '43234(534)'

number=number.replaceAll("[\\D]", "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-d175c098888a> in <module>
#       1 number = '43234(534)'
#       2
# ----> 3 number=number.replaceAll("[\\D]", "")
#
# AttributeError: 'str' object has no attribute 'replaceAll'

# %%
df_macola = pd.read_csv(r"C:\Users\KC\Desktop\WhitespaceProject\Macola.csv")

# %%
df_macola.shape
# Out:
# (48747, 26)
